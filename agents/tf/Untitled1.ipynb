# %%
import tensorflow as tf
from tensorflow.layers import dense

# %%
from tf_agents.networks import categorical_q_network
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-50154f5f2e8d> in <module>()
# ----> 1 from tf_agents.networks import categorical_q_network
#
# ImportError: No module named 'tf_agents'

# %%
state = 5

with tf.variable_scope('dense1'):
    dense1 = dense(state, units_1, [units_1], w_i, b_i)
with tf.variable_scope('dense2'):
    dense2 = dense(dense1, units_2, [units_2], w_i, b_i)
with tf.variable_scope('concat'):
    concatenated = tf.concat([dense2, tf.cast(action, tf.float32)], 1)
with tf.variable_scope('dense3'):
    dense3 = dense(concatenated, atoms, [atoms], w_i, b_i)
        return dense3
